# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Q1). Write a python program to display all the header tags from wikipedia.org.

# %%
page1 = requests.get("https://en.wikipedia.org/wiki/Main_Page")

# %%
page1
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page1.content)

# %%
head=[]
header1 = soup.find_all(['h1','h2','h3','h4','h5','h6'])
for i in header1:
    head.append(i.text.replace("\n",""))

# %%
head
# Out:
# ['Main Page',
#  'Welcome to Wikipedia',
#  "From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages',
#  'Navigation menu',
#  'Personal tools',
#  'Namespaces',
#  'Englishexpandedcollapsed',
#  'Views',
#  'Moreexpandedcollapsed',
#  'Search',
#  'Navigation',
#  'Contribute',
#  'Tools',
#  'Print/export',
#  'In other projects',
#  'Languages']

# %%
wiki_data = pd.DataFrame({"Headers":head})

# %%
wiki_data
# Out:
#                           Headers
# 0                       Main Page
# 1            Welcome to Wikipedia
# 2   From today's featured article
# 3                Did you know ...
# 4                     In the news
# 5                     On this day
# 6        Today's featured picture
# 7        Other areas of Wikipedia
# 8     Wikipedia's sister projects
# 9             Wikipedia languages
# 10                Navigation menu
# 11                 Personal tools
# 12                     Namespaces
# 13       Englishexpandedcollapsed
# 14                          Views
# 15          Moreexpandedcollapsed
# 16                         Search
# 17                     Navigation
# 18                     Contribute
# 19                          Tools
# 20                   Print/export
# 21              In other projects
# 22                      Languages

# %% [markdown]
# # Q2).Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release)

# %%
page2 = requests.get("https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc")
soup2 = BeautifulSoup(page2.content)

# %%
name = soup2.find_all("div",class_="lister-item mode-advanced")
name
# Out:
# [<div class="lister-item mode-advanced">
#  <div class="lister-top-right">
#  <div class="ribbonize" data-caller="filmosearch" data-tconst="tt0111161"></div>
#  </div>
#  <div class="lister-item-image float-left">
#  <a href="/title/tt0111161/"> <img alt="The Shawshank Redemption" class="loadlate" data-tconst="tt0111161" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
#  </a> </div>
#  <div class="lister-item-content">
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt0111161/">The Shawshank Redemption</a>
#  <span class="lister-item-year text-muted unbold">(1994)</span>
#  </h3>
#  <p class="text-muted">
#  <span class="certificate">A</span>
#  <span class="ghost">|</span>
#  <span class="runtime">142 min</span>
# ...

# %%
movies_name=[]
rating2=[]
year=[]

# %%
for i in name:
    movie=i.h3.find("a")
    movies_name.append(movie.text)

# %%
for i in name:
    rate=i.find("div",class_="inline-block ratings-imdb-rating").text.replace("\n","")
    rating2.append(rate)

# %%
for i in name:
    yr=i.find("span",class_="lister-item-year text-muted unbold").text.replace("(","").replace(")","")
    year.append(yr)

# %%
len(movies_name)
# Out:
# 50

# %%
len(rating2)
# Out:
# 50

# %%
len(year)
# Out:
# 50

# %%
imdb_data_1 = pd.DataFrame({"Movie Name":movies_name,"Ratings":rating2,"Year of Release":year})

# %%
imdb_data_1
# Out:
#                                            Movie Name Ratings Year of Release
# 0                            The Shawshank Redemption     9.3            1994
# 1                                       The Godfather     9.2            1972
# 2                                     The Dark Knight     9.1            2008
# 3       The Lord of the Rings: The Return of the King     9.0            2003
# 4                                    Schindler's List     9.0            1993
# 5                              The Godfather: Part II     9.0            1974
# 6                                        12 Angry Men     9.0            1957
# 7   The Lord of the Rings: The Fellowship of the Ring     8.9            2001
# 8                                        Pulp Fiction     8.9            1994
# 9                                           Inception     8.8            2010
# 10              The Lord of the Rings: The Two Towers     8.8            2002
# ...

# %%
page3 = requests.get("https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc&start=51&ref_=adv_nxt")
soup3 = BeautifulSoup(page3.content)

# %%
name1 = soup3.find_all("div",class_="lister-item mode-advanced")

# %%
movies_name1=[]
rating3=[]
year1=[]

# %%
for i in name1:
    movie1=i.h3.find("a")
    movies_name1.append(movie1.text)

# %%
for i in name1:
    rate1=i.find("div",class_="inline-block ratings-imdb-rating").text.replace("\n","")
    rating3.append(rate1)

# %%
for i in name1:
    yr1=i.find("span",class_="lister-item-year text-muted unbold").text.replace("(","").replace(")","")
    year1.append(yr1)

# %%
len(movies_name1)
# Out:
# 50

# %%
len(rating3)
# Out:
# 50

# %%
len(year1)
# Out:
# 50

# %%
imdb_data_2 = pd.DataFrame({"Movie Name":movies_name1,"Ratings":rating3,"Year of Release":year1})

# %%
imdb_data_2
# Out:
#                                            Movie Name Ratings Year of Release
# 0                                      Apocalypse Now     8.5            1979
# 1                                               Alien     8.5            1979
# 2                        Once Upon a Time in the West     8.5            1968
# 3                                              Psycho     8.5            1960
# 4                                         Rear Window     8.5            1954
# 5                                          Casablanca     8.5            1942
# 6                                        Modern Times     8.5            1936
# 7                                         City Lights     8.5            1931
# 8                                          Capharnaüm     8.4            2018
# 9                                               Joker     8.4          I 2019
# 10                                     Kimi no na wa.     8.4            2016
# ...

# %%
data=pd.concat([imdb_data_1,imdb_data_2])

# %%
data
# Out:
#                                        Movie Name Ratings Year of Release
# 0                        The Shawshank Redemption     9.3            1994
# 1                                   The Godfather     9.2            1972
# 2                                 The Dark Knight     9.1            2008
# 3   The Lord of the Rings: The Return of the King     9.0            2003
# 4                                Schindler's List     9.0            1993
# ..                                            ...     ...             ...
# 45                             North by Northwest     8.3            1959
# 46                                        Vertigo     8.3            1958
# 47                            Singin' in the Rain     8.3            1952
# 48                                   Citizen Kane     8.3            1941
# 49              M - Eine Stadt sucht einen Mörder     8.3            1931
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q3).Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. name, rating, year of release)

# %%
page4 = requests.get("https://www.imdb.com/list/ls009997493/")
soup4 = BeautifulSoup(page4.content)

# %%
name = soup4.find_all("div",class_="lister-item-content")

# %%
name
# Out:
# [<div class="lister-item-content">
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt0405508/">Rang De Basanti</a>
#  <span class="lister-item-year text-muted unbold">(2006)</span>
#  </h3>
#  <p class="text-muted text-small">
#  <span class="certificate">UA</span>
#  <span class="ghost">|</span>
#  <span class="runtime">167 min</span>
#  <span class="ghost">|</span>
#  <span class="genre">
#  Comedy, Crime, Drama            </span>
#  </p>
#  <div class="ipl-rating-widget">
#  <div class="ipl-rating-star small">
#  <span class="ipl-rating-star__star">
#  <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z"></path>
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  </svg>
#  </span>
# ...

# %%
movies_name5=[]
rating5=[]
year5=[]

# %%
for i in name:
    movie5=i.h3.find("a")
    movies_name5.append(movie5.text)

# %%
for i in name:
    rate5=i.find("span",class_="ipl-rating-star__rating").text.replace("\n","")
    rating5.append(rate5)

# %%
for i in name:
    yr5=i.find("span",class_="lister-item-year text-muted unbold").text.replace("(","").replace(")","")
    year5.append(yr5)

# %%
len(movies_name5)
# Out:
# 100

# %%
len(rating5)
# Out:
# 100

# %%
len(year5)
# Out:
# 100

# %%
imdb_data_5 = pd.DataFrame({"Movie Name":movies_name5,"Ratings":rating5,"Year of Release":year5})

# %%
imdb_data_5
# Out:
#                 Movie Name Ratings Year of Release
# 0          Rang De Basanti     8.1            2006
# 1                 3 Idiots     8.5            2009
# 2         Taare Zameen Par     8.4            2007
# 3           Dil Chahta Hai     8.1            2001
# 4   Swades: We, the People     8.2            2004
# ..                     ...     ...             ...
# 95             Wake Up Sid     7.6            2009
# 96                Rangeela     7.4            1995
# 97     Shatranj Ke Khilari     7.5            1977
# 98      Pyaar Ka Punchnama     7.7            2011
# 99           Ek Hasina Thi     7.5            2004
#
# [100 rows x 3 columns]

# %% [markdown]
# # 4) Write a python program to scrape product name, price and discounts from https://meesho.com/bagsladies/pl/p7vbp .

# %%
page=requests.get("https://meesho.com/bags-ladies/pl/p7vbp")

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
product_name=[]
for i in soup.find_all('p',class_="Text__StyledText-sc-oo0kvp-0 bWSOET NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS"):
    product_name.append(i.text)
product_name
# Out:
# [' Women Handbags',
#  'Gorgeous Stylish Women Handbags',
#  'Gorgeous Classy Women Handbags',
#  "Elegant Fancy Women's Bags",
#  'Trendy Fancy Women Handbags',
#  'Voguish Fashionable Women Handbags',
#  'Gorgeous Attractive Women Handbags',
#  "Elegant Fancy Women'S Pu Leather Hand Bags",
#  'Ravishing Alluring Women Handbags',
#  'Wonderful Women Women Handbags',
#  'Elite Fancy Women Handbags',
#  'Elite Fancy Women Handbags',
#  'Attractive Women Handbags',
#  'Trendy Attractive Women Handbags',
#  'Classic Attractive Women Handbag',
#  'Gorgeous Versatile Women Handbags',
#  'Voguish Alluring Women Handbags',
#  'Classic Fashionable Women Handbags',
#  'Elegant Classy Women Handbags',
#  'Graceful Attractive Women Handbags']

# %%
price=[]
for i in soup.find_all('h5',class_="Text__StyledText-sc-oo0kvp-0 hiHdyy"):
    a=i.text.replace("₹","")
    price.append(a)
price
# Out:
# ['281',
#  '150',
#  '193',
#  '189',
#  '210',
#  '254',
#  '196',
#  '175',
#  '130',
#  '217',
#  '140',
#  '260',
#  '197',
#  '207',
#  '204',
#  '211',
#  '517',
#  '320',
#  '319',
#  '133']

# %%
discount=[]
for i in soup.find_all('span',class_="Text__StyledText-sc-oo0kvp-0 lnonyH"):
    b=i.text.split()[0]
    discount.append(b)
discount
# Out:
# ['26%',
#  '30%',
#  '30%',
#  '30%',
#  '30%',
#  '28%',
#  '30%',
#  '30%',
#  '30%',
#  '30%',
#  '30%',
#  '28%',
#  '30%',
#  '30%',
#  '30%',
#  '30%',
#  '16%',
#  '24%',
#  '24%',
#  '30%']

# %%
data_meesho=pd.DataFrame({"Product Nmae":product_name,"Price":price,"Discount":discount})

# %%
data_meesho
# Out:
#                                   Product Nmae Price Discount
# 0                               Women Handbags   281      26%
# 1              Gorgeous Stylish Women Handbags   150      30%
# 2               Gorgeous Classy Women Handbags   193      30%
# 3                   Elegant Fancy Women's Bags   189      30%
# 4                  Trendy Fancy Women Handbags   210      30%
# 5           Voguish Fashionable Women Handbags   254      28%
# 6           Gorgeous Attractive Women Handbags   196      30%
# 7   Elegant Fancy Women'S Pu Leather Hand Bags   175      30%
# 8            Ravishing Alluring Women Handbags   130      30%
# 9               Wonderful Women Women Handbags   217      30%
# 10                  Elite Fancy Women Handbags   140      30%
# 11                  Elite Fancy Women Handbags   260      28%
# 12                   Attractive Women Handbags   197      30%
# 13            Trendy Attractive Women Handbags   207      30%
# ...

# %% [markdown]
# # 5) Write a python program to scrape cricket rankings from icc-cricket.com

# %% [markdown]
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/test")

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's Test Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's Test Team Rankings | ICC" property="og:title"/>
# ...

# %%
teams=[]
for i in soup.find_all('span',class_="u-hide-phablet"):
    a=i.text
    teams.append(a)
tea=teams[:10]

# %%
matches=[]
for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    a=i.text
    matches.append(a)
matches
# Out:
# ['32',
#  '3,717',
#  '31',
#  '3,561',
#  '41',
#  '4,151',
#  '26',
#  '2,622',
#  '30',
#  '2,787',
#  '30',
#  '2,485',
#  '33',
#  '2,480',
#  '22',
#  '1,157',
#  '11',
#  '342']

# %%
match=matches[::2]

# %%
for i in soup.find_all('td',class_="rankings-block__banner--matches"):
    a=i.text
    matches.append(a)
matches
# Out:
# ['32',
#  '3,717',
#  '31',
#  '3,561',
#  '41',
#  '4,151',
#  '26',
#  '2,622',
#  '30',
#  '2,787',
#  '30',
#  '2,485',
#  '33',
#  '2,480',
#  '22',
#  '1,157',
#  '11',
#  '342',
#  '23']

# %%
match=matches[::2]
match
# Out:
# ['32', '31', '41', '26', '30', '30', '33', '22', '11', '23']

# %%
point=matches[1::2]
point
for i in soup.find_all('td',class_="rankings-block__banner--points"):
    a=i.text
    point.append(a)
point
# Out:
# ['3,717',
#  '3,561',
#  '4,151',
#  '2,622',
#  '2,787',
#  '2,485',
#  '2,480',
#  '1,157',
#  '342',
#  '2,736']

# %%
ratings=[]
for i in soup.find_all('td',class_="rankings-block__banner--rating u-text-right"):
    a=i.text.replace("\n","").strip()
    ratings.append(a)
ratings
# Out:
# ['119']

# %%
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    a=i.text.replace("\n","").strip()
    ratings.append(a)
ratings
# Out:
# ['119', '116', '115', '101', '101', '93', '83', '75', '53', '31']

# %%
len(teams)
# Out:
# 15

# %%
data_icc1=pd.DataFrame({"Teams":tea,"Matches":match,"Points":point,"Ratings":ratings})

# %%
data_icc1
# Out:
#           Teams Matches Points Ratings
# 0     Australia      32  3,717     119
# 1         India      31  3,561     116
# 2   New Zealand      41  4,151     115
# 3       England      26  2,622     101
# 4  South Africa      30  2,787     101
# 5      Pakistan      30  2,485      93
# 6     Sri Lanka      33  2,480      83
# 7   West Indies      22  1,157      75
# 8    Bangladesh      11    342      53
# 9      Zimbabwe      23  2,736      31

# %% [markdown]
# b) Top 10 ODI Batsmen along with the records of their team and rating.

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi")

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %%
player=[]
for i in soup.find_all('div',class_="rankings-block__banner--name"):
    a=i.text
    player.append(a)
k=[player[0]]

# %%
for i in soup.find_all('td',class_="table-body__cell name"):
    a=i.a.text
    k.append(a)
s=k[:10]
s
# Out:
# ['Babar Azam',
#  'Virat Kohli',
#  'Rohit Sharma',
#  'Quinton de Kock',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'David Warner',
#  'Rassie van der Dussen',
#  'Fakhar Zaman',
#  'Joe Root']

# %%
team1=[]
for i in soup.find_all('div',class_="rankings-block__banner--nationality"):
    a=i.text.replace("\n","").split()[0]
    team1.append(a)
t=[team1[0]]
t
# Out:
# ['PAK']

# %%
t
# Out:
# ['PAK']

# %%
rank=[]
for i in soup.find_all('div',class_="rankings-block__banner--nationality"):
    a=i.text.replace("\n","").split()[1]
    rank.append(a)
w=[rank[0]]

# %%
w
# Out:
# ['873']

# %%
for i in soup.find_all('span',class_="table-body__logo-text"):
    a=i.text.replace("\n","").strip()
    t.append(a)
players_team=t[0:10]

# %%
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    a=i.text.replace("\n","").strip()
    w.append(a)
players_points=w[0:10]

# %%
players_points
# Out:
# ['873', '811', '791', '783', '779', '775', '762', '750', '741', '740']

# %%
data_icc2=pd.DataFrame({"Player":s,"Country":players_team,"Points":players_points})

# %%
data_icc2
# Out:
#                   Player Country Points
# 0             Babar Azam     PAK    873
# 1            Virat Kohli     IND    811
# 2           Rohit Sharma     IND    791
# 3        Quinton de Kock      SA    783
# 4            Aaron Finch     AUS    779
# 5         Jonny Bairstow     ENG    775
# 6           David Warner     AUS    762
# 7  Rassie van der Dussen      SA    750
# 8           Fakhar Zaman     PAK    741
# 9               Joe Root     ENG    740

# %% [markdown]
# c) Top 10 ODI bowlers along with the records of their team and rating.

# %%
bowlers=[]
for i in soup.find_all('div',class_="rankings-block__banner--name"):
    a=i.text
    bowlers.append(a)
bowl=[player[1]]

# %%
bowl
# Out:
# ['Trent Boult']

# %%
for i in soup.find_all('td',class_="table-body__cell name"):
    a=i.a.text
    bowl.append(a)

# %%
ballers=bowl[:10]

# %%
ballers
# Out:
# ['Trent Boult',
#  'Virat Kohli',
#  'Rohit Sharma',
#  'Quinton de Kock',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'David Warner',
#  'Rassie van der Dussen',
#  'Fakhar Zaman',
#  'Joe Root']

# %%
baller_country1=[]
for i in soup.find_all('div',class_="rankings-block__banner--nationality"):
    a=i.text.replace("\n","").split()[0]
    baller_country1.append(a)
baller_nation1=[team1[1]]

# %%
baller_nation1
# Out:
# ['NZ']

# %%
bowler_rank=[]
for i in soup.find_all('div',class_="rankings-block__banner--nationality"):
    a=i.text.replace("\n","").split()[1]
    bowler_rank.append(a)
ballers_rank=[rank[1]]

# %%
ballers_rank
# Out:
# ['737']

# %%
for i in soup.find_all('span',class_="table-body__logo-text"):
    a=i.text.replace("\n","").strip()
    baller_nation1.append(a)
ballers_nation1=baller_nation1[0:10]

# %%
ballers_nation1
# Out:
# ['NZ', 'IND', 'IND', 'SA', 'AUS', 'ENG', 'AUS', 'SA', 'PAK', 'ENG']

# %%
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    a=i.text.replace("\n","").strip()
    ballers_rank.append(a)
bowl_rank=ballers_rank[0:10]

# %%
bowl_rank
# Out:
# ['737', '811', '791', '783', '779', '775', '762', '750', '741', '740']

# %%
data_icc3=pd.DataFrame({"Bowlers":ballers,"Country":ballers_nation1,"Points":bowl_rank})

# %%
data_icc3
# Out:
#                  Bowlers Country Points
# 0            Trent Boult      NZ    737
# 1            Virat Kohli     IND    811
# 2           Rohit Sharma     IND    791
# 3        Quinton de Kock      SA    783
# 4            Aaron Finch     AUS    779
# 5         Jonny Bairstow     ENG    775
# 6           David Warner     AUS    762
# 7  Rassie van der Dussen      SA    750
# 8           Fakhar Zaman     PAK    741
# 9               Joe Root     ENG    740

# %% [markdown]
# # 6) Write a python program to scrape cricket rankings from icc-cricket.com.

# %% [markdown]
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
teams_women=[]
for i in soup.find_all('span',class_="u-hide-phablet"):
    a=i.text
    teams_women.append(a)
tea_women=teams_women[:10]

# %%
tea_women
# Out:
# ['Australia',
#  'South Africa',
#  'England',
#  'India',
#  'New Zealand',
#  'Bangladesh',
#  'West Indies',
#  'Pakistan',
#  'Ireland',
#  'Sri Lanka']

# %%
points3=[]
for i in soup.find_all('td',class_="rankings-block__banner--matches"):
    a=i.text.replace("\n","").strip()
    points3.append(a)
points3
# Out:
# ['20']

# %%
points4=[]

# %%
for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    a=i.text.replace("\n","").strip()
    points4.append(a)
g=points4[::2]

# %%
points3.extend(g)

# %%
b=points3[:10]

# %%
points5=[]
for i in soup.find_all('td',class_="rankings-block__banner--points"):
    a=i.text.replace("\n","").strip()
    points5.append(a)
points5
# Out:
# ['3,263']

# %%
points6=[]
for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    a=i.text.replace("\n","").strip()
    points6.append(a)
l=points6[1::2]

# %%
l
# Out:
# ['2,580',
#  '2,474',
#  '2,221',
#  '2,342',
#  '475',
#  '1,801',
#  '1,304',
#  '240',
#  '233',
#  '0']

# %%
points5.extend(l)
d=points5[:10]

# %%
d
# Out:
# ['3,263',
#  '2,580',
#  '2,474',
#  '2,221',
#  '2,342',
#  '475',
#  '1,801',
#  '1,304',
#  '240',
#  '233']

# %%
rate=[]
for i in soup.find_all('td',class_="rankings-block__banner--rating u-text-right"):
    a=i.text.replace("\n","").strip()
    rate.append(a)
rate
# Out:
# ['163']

# %%
rate1=[]
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    a=i.text.replace("\n","").strip()
    rate1.append(a)
j=rate1

# %%
j
# Out:
# ['123', '118', '101', '98', '95', '86', '69', '48', '47', '0']

# %%
rate.extend(j)
p=rate[:10]

# %%
p
# Out:
# ['163', '123', '118', '101', '98', '95', '86', '69', '48', '47']

# %%
data_icc4=pd.DataFrame({"Team":tea_women,"Matches":b,"Points":d,"Ratings":p})

# %%
data_icc4
# Out:
#            Team Matches Points Ratings
# 0     Australia      20  3,263     163
# 1  South Africa      21  2,580     123
# 2       England      21  2,474     118
# 3         India      22  2,221     101
# 4   New Zealand      24  2,342      98
# 5    Bangladesh       5    475      95
# 6   West Indies      21  1,801      86
# 7      Pakistan      19  1,304      69
# 8       Ireland       5    240      48
# 9     Sri Lanka       5    233      47

# %% [markdown]
# b)Top 10 women’s ODI  players along with the records of their team and rating

# %%
page1 = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi")

# %%
page1
# Out:
# <Response [200]>

# %%
soup1 = BeautifulSoup(page1.content)

# %%
Team_data1 = soup1.find_all("td","table-body__cell name")
Batswomen_name = []
for i in Team_data1:
    span = i.a.text
    Batswomen_name.append(span)

# %%
Batswomen_name
# Out:
# ['Mithali Raj',
#  'Tammy Beaumont',
#  'Meg Lanning',
#  'Beth Mooney',
#  'Lizelle Lee',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Laura Wolvaardt',
#  'Ellyse Perry',
#  'Sophie Ecclestone',
#  'Megan Schutt',
#  'Jhulan Goswami',
#  'Shabnim Ismail',
#  'Ellyse Perry',
#  'Ayabonga Khaka',
#  'Marizanne Kapp',
#  'Katherine Brunt',
#  'Kate Cross',
#  'Natalie Sciver',
#  'Marizanne Kapp',
#  'Amelia Kerr',
#  'Deepti Sharma',
#  'Katherine Brunt',
#  'Jess Jonassen',
#  'Stafanie Taylor',
#  'Ashleigh Gardner',
#  'Hayley Matthews']

# %%
Batswomen_Team = []
Team_Name = soup1.find_all("span","table-body__logo-text")

for i in Team_Name:
    Batswomen_Team.append(i.text)

# %%
Batswomen_Team
# Out:
# ['IND',
#  'ENG',
#  'AUS',
#  'AUS',
#  'SA',
#  'NZ',
#  'IND',
#  'SA',
#  'AUS',
#  'ENG',
#  'AUS',
#  'IND',
#  'SA',
#  'AUS',
#  'SA',
#  'SA',
#  'ENG',
#  'ENG',
#  'ENG',
#  'SA',
#  'NZ',
#  'IND',
#  'ENG',
#  'AUS',
#  'WI',
#  'AUS',
#  'WI']

# %%
Batswomen_Rating = []
Rating = soup1.find_all("td","table-body__cell u-text-right rating")

for i in Rating:
    Batswomen_Rating.append(i.text)

# %%
Batswomen_Rating
# Out:
# ['735',
#  '707',
#  '706',
#  '705',
#  '702',
#  '700',
#  '666',
#  '661',
#  '661',
#  '746',
#  '735',
#  '695',
#  '689',
#  '663',
#  '661',
#  '660',
#  '648',
#  '603',
#  '351',
#  '327',
#  '312',
#  '309',
#  '273',
#  '263',
#  '262',
#  '256',
#  '254']

# %%
Batswomen_name = Batswomen_name[:9]
Batswomen_Rating = Batswomen_Rating[:9]
Batswomen_Team = Batswomen_Team[:9]

# %%
Batswomen_name.insert(0,"Tammy Beaumont")

# %%
Batswomen_Rating.insert(0,765)

# %%
Batswomen_Team.insert(0,"ENG")

# %%
ICC_data2 = pd.DataFrame({})
ICC_data2['Player_Name']= Batswomen_name
ICC_data2['Team'] = Batswomen_Team
ICC_data2['Rating'] = Batswomen_Rating
ICC_data2
# Out:
#          Player_Name Team Rating
# 0     Tammy Beaumont  ENG    765
# 1        Mithali Raj  IND    735
# 2     Tammy Beaumont  ENG    707
# 3        Meg Lanning  AUS    706
# 4        Beth Mooney  AUS    705
# 5        Lizelle Lee   SA    702
# 6  Amy Satterthwaite   NZ    700
# 7    Smriti Mandhana  IND    666
# 8    Laura Wolvaardt   SA    661
# 9       Ellyse Perry  AUS    661

# %% [markdown]
#  c)Top 10 women’s ODI All rounder players along with the records of their team and rating

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder")

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI All Rounder | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI All Rounder | Player Rankings | ICC" property="og:title"/>
# ...

# %%
players_b=[]
for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    a=i.text
    players_b.append(a)

# %%
players_b
# Out:
# ['Ellyse Perry']

# %%
for i in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    a=i.a.text
    players_b.append(a)

# %%
pls=players_b[:10]

# %%
pls
# Out:
# ['Ellyse Perry',
#  'Natalie Sciver',
#  'Marizanne Kapp',
#  'Amelia Kerr',
#  'Deepti Sharma',
#  'Katherine Brunt',
#  'Jess Jonassen',
#  'Stafanie Taylor',
#  'Ashleigh Gardner',
#  'Hayley Matthews']

# %%
team11=[]
for i in soup.find_all('div',class_="rankings-block__banner--nationality"):
    a=i.text.replace("\n","").split()[0]
    team11.append(a)
t1=[team11[0]]

# %%
t1
# Out:
# ['AUS']

# %%
rank11=[]
for i in soup.find_all('div',class_="table-body__logo-text"):
    a=i.text.replace("\n","").split()[1]
    rank11.append(a)
w1=[rank[0]]

# %%
w1
# Out:
# ['873']

# %%
for i in soup.find_all('span',class_="table-body__logo-text"):
    a=i.text.replace("\n","").strip()
    t1.append(a)
players_team1=t1[0:10]

# %%
players_team1
# Out:
# ['AUS', 'ENG', 'SA', 'NZ', 'IND', 'ENG', 'AUS', 'WI', 'AUS', 'WI']

# %%
for i in soup.find_all('td',class_="table-body__cell rating"):
    a=i.text.replace("\n","").strip()
    w1.append(a)
players_points1=w1[0:10]

# %%
players_points1
# Out:
# ['873', '351', '327', '312', '309', '273', '263', '262', '256', '254']

# %%
data_icc8=pd.DataFrame({"Player":pls,"Country":players_team1,"Points":players_points1})

# %%
data_icc8
# Out:
#              Player Country Points
# 0      Ellyse Perry     AUS    873
# 1    Natalie Sciver     ENG    351
# 2    Marizanne Kapp      SA    327
# 3       Amelia Kerr      NZ    312
# 4     Deepti Sharma     IND    309
# 5   Katherine Brunt     ENG    273
# 6     Jess Jonassen     AUS    263
# 7   Stafanie Taylor      WI    262
# 8  Ashleigh Gardner     AUS    256
# 9   Hayley Matthews      WI    254

# %% [markdown]
# # 7) Write a python program to scrape details of all the posts from coreyms.com. Scrape the heading, date, content and the code for the video from the link for the youtube video from the post

# %%
page=requests.get("https://coreyms.com/")

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- This site is optimized with the Yoast SEO plugin v15.4 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>CoreyMS - Development, Design, DIY, and more</title>
# <meta content="Development, Design, DIY, and more" name="description"/>
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <link href="https://coreyms.com/" rel="canonical"/>
# <link href="https://coreyms.com/page/2" rel="next"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="CoreyMS - Development, Design, DIY, and more" property="og:title"/>
# <meta content="Development, Design, DIY, and more" property="og:description"/>
# <meta content="https://coreyms.com/" property="og:url"/>
# <meta content="CoreyMS" property="og:site_name"/>
# ...

# %%
heading=[]
for i in soup.find_all('a',class_="entry-title-link"):
    a=i.text
    heading.append(a)

# %%
heading
# Out:
# ['Python Tutorial: Zip Files – Creating and Extracting Zip Archives',
#  'Python Data Science Tutorial: Analyzing the 2019 Stack Overflow Developer Survey',
#  'Python Multiprocessing Tutorial: Run Code in Parallel Using the Multiprocessing Module',
#  'Python Threading Tutorial: Run Code Concurrently Using the Threading Module',
#  'Update (2019-09-03)',
#  'Python Quick Tip: The Difference Between “==” and “is” (Equality vs Identity)',
#  'Python Tutorial: Calling External Commands Using the Subprocess Module',
#  'Visual Studio Code (Windows) – Setting up a Python Development Environment and Complete Overview',
#  'Visual Studio Code (Mac) – Setting up a Python Development Environment and Complete Overview',
#  'Clarifying the Issues with Mutable Default Arguments']

# %%
date=[]
for i in soup.find_all('time',class_="entry-time"):
    a=i.text
    date.append(a)

# %%
date
# Out:
# ['November 19, 2019',
#  'October 17, 2019',
#  'September 21, 2019',
#  'September 12, 2019',
#  'September 3, 2019',
#  'August 6, 2019',
#  'July 24, 2019',
#  'May 1, 2019',
#  'May 1, 2019',
#  'April 24, 2019']

# %%
content=[]
for i in soup.find_all('div',class_="entry-content"):
    a=i.p.text
    content.append(a)

# %%
content
# Out:
# ['In this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…',
#  'In this Python Programming video, we will be learning how to download and analyze real-world data from the 2019 Stack Overflow Developer Survey. This is terrific practice for anyone getting into the data science field. We will learn different ways to analyze this data and also some best practices. Let’s get started…',
#  'In this Python Programming video, we will be learning how to run code in parallel using the multiprocessing module. We will also look at how to process multiple high-resolution images at the same time using a ProcessPoolExecutor from the concurrent.futures module. Let’s get started…',
# ...

# %%
for article in soup.find_all("article"):
    video=article.find('iframe',class_="youtube-player")["src"]
    print(video)
# Out:
# https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent
# https://www.youtube.com/embed/_P7X8tMplsw?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent
# https://www.youtube.com/embed/fKl2JW_qrso?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent
# https://www.youtube.com/embed/IEEhzQoKtQU?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14108/3027214644.py in <module>
#       1 for article in soup.find_all("article"):
# ----> 2     video=article.find('iframe',class_="youtube-player")["src"]
#       3     print(video)
#       4
#
# ...

# %% [markdown]
# # 8) Write a python program to scrape house details from mentioned URL. It should include house title, location, area, EMI and price from https://www.nobroker.in/ .Enter three localities which are Indira Nagar, Jayanagar,  Rajaji Nagar.

# %%
page=requests.get("https://www.nobroker.in/property/rent/bangalore/multiple?searchParam=...&radius=2.0&sharedAccomodation=0&city=bangalore&locality=Indiranagar,&locality=Rajajinagar,&locality=Jayanagar")

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <!--<meta charset="utf-8"/>-->
# <meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %%
area=[]
for i in soup.find_all('h2',class_="heading-6 flex items-center font-semi-bold m-0"):
    a=i.span.text
    area.append(a)

# %%
area
# Out:
# ['2 BHK Flat  For Rent  In Standalone In Srirampura',
#  '3 BHK Apartment  For Rent  In Team Green Wood Apartment In Indira Nagar',
#  '1 BHK Flat  For Rent  In Rajaji Nagar',
#  '2 BHK In Independent House  For Rent  In Jayanagar',
#  '2 BHK In Independent House  For Rent  In Jayanagara 9th Block, Jayanagar']

# %%
location=[]
for i in soup.find_all('div',class_="mt-0.5p overflow-hidden overflow-ellipsis whitespace-nowrap max-w-70 text-gray-light leading-4 po:mb-0 po:max-w-95"):
    a=i.text
    location.append(a)

# %%
location
# Out:
# ['Srirampura, near Srirampura Metro Station',
#  'Team Green Wood Apartment\xa0 Team Green Wood apartment, 3rd Main Road, Indira Nagar 1st Stage, H Colony, Indiranagar, Bengaluru, Karnataka, India',
#  'Standalone Building, Rajajinagar RTO, 12th Main Road, 2nd Block, Rajaji Nagar, Bengaluru, Karnataka, India',
#  'Independent House, Nal layout, behind Jal Bhavan',
#  'Independent House, 36th A Cross']

# %%
Emi1=[]
for i in soup.find_all('div',class_="font-semi-bold heading-6"):
    b=i.text.split()
    Emi1.append(b)
Emi1
# Out:
# [['850', 'sqft'],
#  ['₹1,50,000'],
#  ['₹', '12,200No', 'Extra', 'Maintenance'],
#  ['1,730', 'sqft'],
#  ['₹3,60,000'],
#  ['₹', '62,000', '+₹', '2,750Maintenance'],
#  ['500', 'sqft'],
#  ['₹75,000'],
#  ['₹', '10,000', '+₹', '300Maintenance'],
#  ['1,400', 'sqft'],
#  ['₹1,50,000'],
#  ['₹', '22,800No', 'Extra', 'Maintenance'],
#  ['800', 'sqft'],
#  ['₹1,00,000'],
#  ['₹', '16,000No', 'Extra', 'Maintenance']]

# %%
price=[]
for i in soup.find_all('div',class_="font-semi-bold heading-6"):
    a=i.text.split()
a[1]
# Out:
# '16,000No'

# %%
price_emi1=[]
for i in soup.find_all('div',class_="font-semi-bold heading-6"):
    a=i.text.split()
    price_emi1.append(a)
price_emi1[1::3]
# Out:
# [['₹1,50,000'], ['₹3,60,000'], ['₹75,000'], ['₹1,50,000'], ['₹1,00,000']]

# %% [markdown]
# # Q9) Write a python program to scrape mentioned details from dineout.co.in :i) Restaurant name ii) Cuisine iii) Location iv) Ratings v) Image URL

# %%
page1 = requests.get("https://www.dineout.co.in/delhi-restaurants/buffet-special")

# %%
page1
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page1.content)

# %%
rest=[]
for i in soup.find_all("a",class_="restnt-name ellipsis"):
    a=i.text
    rest.append(a)
rest
# Out:
# ['Castle Barbeque',
#  'Jungle Jamboree',
#  'Cafe Knosh',
#  'Castle Barbeque',
#  'The Barbeque Company',
#  'India Grill',
#  'Delhi Barbeque',
#  'The Monarch - Bar Be Que Village',
#  'World Cafe',
#  'Indian Grill Room',
#  'Mad 4 Bar B Que',
#  'Barbeque 29',
#  'Glasshouse']

# %%
cus=[]
for i in soup.find_all("span",class_="double-line-ellipsis"):
    cus.append(i.text.split()[6:9])
cus
# Out:
# [['North', 'Indian,', 'Chinese'],
#  ['North', 'Indian,', 'Asian,'],
#  ['Italian,', 'Continental'],
#  ['Chinese,', 'North', 'Indian'],
#  ['North', 'Indian,', 'Chinese'],
#  ['North', 'Indian,', 'Italian'],
#  ['North', 'Indian'],
#  ['North', 'Indian,', 'Chinese'],
#  ['North', 'Indian,', 'Chinese,'],
#  ['North', 'Indian,', 'Mughlai'],
#  ['North', 'Indian,', 'Mughlai'],
#  ['North', 'Indian,', 'Chinese'],
#  ['European,', 'Italian,', 'Asian,']]

# %%
loc=[]
for i in soup.find_all("div",class_="restnt-loc ellipsis"):
    a=i.text
    loc.append(a)
loc
# Out:
# ['Connaught Place, Central Delhi',
#  '3CS Mall,Lajpat Nagar - 3, South Delhi',
#  'The Leela Ambience Convention Hotel,Shahdara, East Delhi',
#  'Pacific Mall,Tagore Garden, West Delhi',
#  'Gardens Galleria,Sector 38A, Noida',
#  'Hilton Garden Inn,Saket, South Delhi',
#  'Taurus Sarovar Portico,Mahipalpur, South Delhi',
#  'Indirapuram Habitat Centre,Indirapuram, Ghaziabad',
#  'Vibe by The Lalit Traveller,Sector 35, Faridabad',
#  'Suncity Business Tower,Golf Course Road, Gurgaon',
#  'Sector 29, Faridabad',
#  'NIT, Faridabad',
#  'DoubleTree By Hilton Gurugram Baani Square,Sector 50, Gurgaon']

# %%
rat=[]
for i in soup.find_all("div",class_="restnt-rating rating-4"):
    a=i.text
    rat.append(a)
rat
# Out:
# ['3.5',
#  '3.9',
#  '4.3',
#  '3.9',
#  '4',
#  '3.9',
#  '3.7',
#  '3.9',
#  '4.3',
#  '4.3',
#  '3.6',
#  '4.2',
#  '4.1']

# %%
im=[]
for i in soup.find_all("img",class_="no-img"):
    a=i['data-src']
    im.append(a)
im
# Out:
# ['https://im1.dineout.co.in/images/uploads/restaurant/sharpen/8/k/b/p86792-16062953735fbe1f4d3fb7e.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/h/c/p3643-144497865356209fdd65746.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/p/m/p406-15438184745c04ccea491bc.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/j/o/p38113-15959192065f1fcb666130c.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/q/d/p79307-16051787075fad15532bd7c.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/v/t/p2687-1482477169585cce712b90f.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/v/f/p52501-16006856545f68865616659.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/n/o/p34822-15599107305cfa594a13c24.jpg?tr=tr:n-medium',
# ...

# %%
data_dine=pd.DataFrame({"Restaurant":rest,"Cuisine":cus,"Location":loc,"Rating":rat,"URL":im})

# %%
data_dine
# Out:
#                           Restaurant                        Cuisine  \
# 0                    Castle Barbeque      [North, Indian,, Chinese]
# 1                    Jungle Jamboree       [North, Indian,, Asian,]
# 2                         Cafe Knosh        [Italian,, Continental]
# 3                    Castle Barbeque      [Chinese,, North, Indian]
# 4               The Barbeque Company      [North, Indian,, Chinese]
# 5                        India Grill      [North, Indian,, Italian]
# 6                     Delhi Barbeque                [North, Indian]
# 7   The Monarch - Bar Be Que Village      [North, Indian,, Chinese]
# 8                         World Cafe     [North, Indian,, Chinese,]
# 9                  Indian Grill Room      [North, Indian,, Mughlai]
# 10                   Mad 4 Bar B Que      [North, Indian,, Mughlai]
# 11                       Barbeque 29      [North, Indian,, Chinese]
# 12                        Glasshouse  [European,, Italian,, Asian,]
#
# ...

# %% [markdown]
# # 10) Write a python program to scrape first 10 product details which include product name , price , Image URL fromhttps://www.bewakoof.com/women-tshirts?ga_q=tshirts .

# %%
page1 = requests.get("https://www.bewakoof.com/women-tshirts?ga_q=tshirts")

# %%
page1
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page1.content)

# %%
pr=[]
for i in soup.find_all("h3"):
    a=i.text
    pr.append(a)
pr=pr[0:10]

# %%
pr
# Out:
# ['Donut Worry Half Sleeve T-Shirt Pineapple Yellow',
#  'Sleepy Cat',
#  'Simply Pawfect Half Sleeve T-Shirt (DL) Tropical blue',
#  'Peace Jerry Half Sleeve Printed T-Shirt (TJL) White',
#  'All We Have Half Sleeve T-Shirt Meteor Grey',
#  'Moody',
#  'Inner Peace Half Sleeve Printed T-Shirt Black',
#  'Beach Blue Half Sleeve T-Shirt',
#  'Digi Teal Half Sleeve T-Shirt',
#  "Nakhre always On Women's Printed White T-shirt"]

# %%
pric=[]
for i in soup.find_all("span",class_="discountedPriceText"):
    a=i.text.split()[1]
    pric.append(a)
pric
# Out:
# ['299', '349', '299', '299', '199', '349', '349', '249', '299', '299']

# %%
imi=[]
for i in soup.find_all("img",class_="productImgTag"):
    a=i['src']
    imi.append(a)
imi
# Out:
# ['https://images.bewakoof.com/t320/donut-worry-half-sleeve-t-shirt-pineapple-yellow-women-s-half-sleeve-printed-t-shirt-291941-1602573790.jpg',
#  'https://images.bewakoof.com/t320/sleepy-cat-half-sleeve-printed-t-shirts-black-women-s-half-sleeve-printed-t-shirt-295717-1603970467.jpg',
#  'https://images.bewakoof.com/t320/simply-pawfect-half-sleeve-t-shirt-dl-tropical-blue-women-s-half-sleeve-printed-t-shirt-295812-1604292711.jpg',
#  'https://images.bewakoof.com/t320/peace-jerry-half-sleeve-printed-t-shirt-tjl-white-women-s-half-sleeve-printed-t-shirt-295801-1603465610.jpg',
#  'https://images.bewakoof.com/t320/all-we-have-half-sleeve-t-shirt-meteor-grey-women-s-half-sleeve-printed-t-shirt-287646-1601034494.jpg',
#  'https://images.bewakoof.com/t320/moody-half-sleeve-printed-t-shirt-white-women-s-half-sleeve-printed-t-shirt-329373-1612528288.jpg',
# ...

# %%
data_bewakoof=pd.DataFrame({"Product Name":pr,"Price":pric,"URL":imi})

# %%
data_bewakoof
# Out:
#                                         Product Name Price  \
# 0   Donut Worry Half Sleeve T-Shirt Pineapple Yellow   299
# 1                                         Sleepy Cat   349
# 2  Simply Pawfect Half Sleeve T-Shirt (DL) Tropic...   299
# 3  Peace Jerry Half Sleeve Printed T-Shirt (TJL) ...   299
# 4        All We Have Half Sleeve T-Shirt Meteor Grey   199
# 5                                              Moody   349
# 6      Inner Peace Half Sleeve Printed T-Shirt Black   349
# 7                     Beach Blue Half Sleeve T-Shirt   249
# 8                      Digi Teal Half Sleeve T-Shirt   299
# 9     Nakhre always On Women's Printed White T-shirt   299
#
#                                                  URL
# 0  https://images.bewakoof.com/t320/donut-worry-h...
# 1  https://images.bewakoof.com/t320/sleepy-cat-ha...
# 2  https://images.bewakoof.com/t320/simply-pawfec...
# 3  https://images.bewakoof.com/t320/peace-jerry-h...
# ...
