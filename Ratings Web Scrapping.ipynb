# %% [markdown]
# # Web Scraping for Rating

# %%
#importing the required library
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
def get_template(search_term,page_no=1):
    """Generate a URL for search Term with page number"""
    search_term = search_term.replace(' ','+')
    template = f'https://www.amazon.in/s?k={search_term}&page={page_no}&qid=1623864210&ref=sr_pg_{page_no}'
    
    return template

# %%
def get_url():#the function that generated URL with the search tearm.
    iteams = ['laptops', 'Phones', 'Headphones', 'smart watches', 'Professional Cameras', 'Printers', 'scanners', 'keyboard', 'monitors', 'Home theater', 'router']
    URL = []     
    for i in iteams:
        for j in range(1,11):
            URL.append(get_template(i,j))
    return URL

# %%
def get_review_url(): #the function that scraps the URL of the front page of the reviews and rattings with the search tearm.
    
    hreff = []
    driver = webdriver.Chrome(executable_path='C:\\Users\\HP\\chromedriver.exe')
    driver.maximize_window()

    URL = get_url()
    for i in URL:
        driver.get(i) #Opening with the URL template

        for i in driver.find_elements_by_xpath("//div[@class = 'a-row a-size-small']//a[@class = 'a-link-normal']"):
            hreff.append(i.get_attribute("href"))
    driver.close()    
    return hreff

# %%
hreff1 = get_review_url()

# %%
len(hreff1)
# Out:
# 1993

# %%
def get_review(): #the function that scraps the URL of all the reviews and rattings
    
    driver = webdriver.Chrome(executable_path='C:\\Users\\HP\\chromedriver.exe') #Calling the Web Driver
    driver.maximize_window()
    rattings = []
    review = []

    for i in hreff1[:400]: #--->> First DataFrame
        driver.get(i) #Opening with the URL template
        
        try: #scraping the URL of the full review pages
            link = driver.find_element_by_xpath("//a[@data-hook='see-all-reviews-link-foot']")
            link = link.get_attribute("href")
            link= link.split('ref=cm')[0]
        except:
            pass     
        
        for i in range(1,5): #Scraping Reviews and Rattings
            l1= f'ref=cm_cr_getr_d_paging_btm_next_{i}?ie=UTF8&reviewerType=all_reviews&pageNumber={i}'
            l = link+ l1 
            
            
            driver.get(l)
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            results = soup.find_all('div',{'class' : 'a-section celwidget'})
        
            for item in results:
                    try:
                        rev = item.find('span', {'data-hook': "review-body"})
                        atag = item.find(['a'], class_ = "a-link-normal")
                        if rev.span.text.replace('\n','').strip() and atag['title'][0]:
                            review.append(rev.span.text.replace('\n','').strip())
                            rattings.append(atag['title'][0])
                        else:
                            break
                    except:
                        break
       
    driver.close()
    
    rat = pd.DataFrame({'Rattings':rattings, "Review": review})
    
    #saving the dataframe in csv
    rat.to_csv("Rattings1.csv",index=False) #Creating CSV
    
    return rat

# %%
Rat = get_review()

# %%
Rat
# Out:
#      Rattings                                             Review
# 0           3  PROS1. Its touch screen2. it doesn't have any ...
# 1           3  Pros1. Boots within 5 seconds (I bet u might h...
# 2           1  Screen is not upto the mark at this price poin...
# 3           4  The device is great when it comes to built qua...
# 4           4  The laptop arrived in a good condition and it ...
# ...       ...                                                ...
# 8975        5  I am fully satisfied with this neck band, buil...
# 8976        3  kaam chalau hai maja nhi hai maine same kharid...
# 8977        1  Surprisingly charging cable was missing!very p...
# 8978        5                                    Good luck shoun
# 8979        5  Quality of material used is also good. Sound q...
#
# [8980 rows x 2 columns]

# %%
def get_review():  #the function that scraps the URL of all the reviews and rattings
    
    driver = webdriver.Chrome(executable_path='C:\\Users\\HP\\chromedriver.exe') #Calling the Web Driver
    driver.maximize_window()
    rattings = []
    review = []

    for i in hreff1[400:800]:#--->> second DataFrame
        driver.get(i) #Opening with the URL template
        
        try: #scraping the URL of the full review pages
            link = driver.find_element_by_xpath("//a[@data-hook='see-all-reviews-link-foot']")
            link = link.get_attribute("href")
            link= link.split('ref=cm')[0]
        except:
            pass     
        
        for i in range(1,5):  #Scraping Reviews and Rattings
            l1= f'ref=cm_cr_getr_d_paging_btm_next_{i}?ie=UTF8&reviewerType=all_reviews&pageNumber={i}'
            l = link+ l1 
            
            
            driver.get(l)
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            results = soup.find_all('div',{'class' : 'a-section celwidget'})
        
            for item in results:
                    try:
                        rev = item.find('span', {'data-hook': "review-body"})
                        atag = item.find(['a'], class_ = "a-link-normal")
                        if rev.span.text.replace('\n','').strip() and atag['title'][0]:
                            review.append(rev.span.text.replace('\n','').strip())
                            rattings.append(atag['title'][0])
                        else:
                            break
                    except:
                        break
       
    driver.close()
    
    rat = pd.DataFrame({'Rattings':rattings, "Review": review})
    
    #saving the dataframe in csv
    rat.to_csv("Rattings2.csv",index=False) #Creating CSV
    
    return rat

# %%
Rat = get_review()
Rat
# Out:
#       Rattings                                             Review
# 0            5  First of all its a very good product consideri...
# 1            5  I bought 2 of this Bluetooth earphones for me ...
# 2            5  The main thing which I found very fascinating ...
# 3            5  The product just wonderful Amazing sound quali...
# 4            5  These Bluetooth headsets are great in this ran...
# ...        ...                                                ...
# 10573        3  Good thing is that its picture quality is bett...
# 10574        3  No camera bag and memory card were provided du...
# 10575        5  Fantastic camera and zoom very good for basic ...
# 10576        4     Handiling is risky. Need some time to get hold
# 10577        4  I have read some disappointing reviews from bu...
#
# [10578 rows x 2 columns]

# %%
def get_review():  #the function that scraps the URL of all the reviews and rattings
    
    driver = webdriver.Chrome(executable_path='C:\\Users\\HP\\chromedriver.exe') #Calling the Web Driver
    driver.maximize_window()
    rattings = []
    review = []

    for i in hreff1[800:1200]:#--->> second DataFrame
        driver.get(i) #Opening with the URL template
        
        try: #scraping the URL of the full review pages
            link = driver.find_element_by_xpath("//a[@data-hook='see-all-reviews-link-foot']")
            link = link.get_attribute("href")
            link= link.split('ref=cm')[0]
        except:
            pass     
        
        for i in range(1,5):  #Scraping Reviews and Rattings
            l1= f'ref=cm_cr_getr_d_paging_btm_next_{i}?ie=UTF8&reviewerType=all_reviews&pageNumber={i}'
            l = link+ l1 
            
            
            driver.get(l)
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            results = soup.find_all('div',{'class' : 'a-section celwidget'})
        
            for item in results:
                    try:
                        rev = item.find('span', {'data-hook': "review-body"})
                        atag = item.find(['a'], class_ = "a-link-normal")
                        if rev.span.text.replace('\n','').strip() and atag['title'][0]:
                            review.append(rev.span.text.replace('\n','').strip())
                            rattings.append(atag['title'][0])
                        else:
                            break
                    except:
                        break
       
    driver.close()
    
    rat = pd.DataFrame({'Rattings':rattings, "Review": review})
    
    #saving the dataframe in csv
    rat.to_csv("Rattings3.csv",index=False) #Creating CSV
    
    return rat

# %%
Rat = get_review()
Rat
# Out:
#      Rattings                                             Review
# 0           4  Canon 5D Mark IV Key SpecificationsNew 30.4MP ...
# 1           5  Used this 5d mark for 7 days as contract.Used ...
# 2           5  Feeling pain in right side after buy ... Camer...
# 3           3  Camera is really good, but available outside a...
# 4           4               rupee deal on this one for prime day
# ...       ...                                                ...
# 7626        2                             Don't buy this printer
# 7627        5                                                  👍
# 7628        4                                                 Ok
# 7629        5        Great scanning speed and feeding stability!
# 7630        5        Great scanning speed and feeding stability!
#
# [7631 rows x 2 columns]

# %%
def get_review():  #the function that scraps the URL of all the reviews and rattings
    
    driver = webdriver.Chrome(executable_path='C:\\Users\\HP\\chromedriver.exe') #Calling the Web Driver
    driver.maximize_window()
    rattings = []
    review = []

    for i in hreff1[1200:1600]:#--->> second DataFrame
        driver.get(i) #Opening with the URL template
        
        try: #scraping the URL of the full review pages
            link = driver.find_element_by_xpath("//a[@data-hook='see-all-reviews-link-foot']")
            link = link.get_attribute("href")
            link= link.split('ref=cm')[0]
        except:
            pass     
        
        for i in range(1,5):  #Scraping Reviews and Rattings
            l1= f'ref=cm_cr_getr_d_paging_btm_next_{i}?ie=UTF8&reviewerType=all_reviews&pageNumber={i}'
            l = link+ l1 
            
            
            driver.get(l)
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            results = soup.find_all('div',{'class' : 'a-section celwidget'})
        
            for item in results:
                    try:
                        rev = item.find('span', {'data-hook': "review-body"})
                        atag = item.find(['a'], class_ = "a-link-normal")
                        if rev.span.text.replace('\n','').strip() and atag['title'][0]:
                            review.append(rev.span.text.replace('\n','').strip())
                            rattings.append(atag['title'][0])
                        else:
                            break
                    except:
                        break
       
    driver.close()
    
    rat = pd.DataFrame({'Rattings':rattings, "Review": review})
    
    #saving the dataframe in csv
    rat.to_csv("Rattings4.csv",index=False) #Creating CSV
    
    return rat

# %%
Rat = get_review()
Rat
# Out:
#      Rattings                                             Review
# 0           5                                                Bad
# 1           4                                               like
# 2           1  Very poor printing and scanning quality...Diff...
# 3           1  Hi, This printer was connected to my main syst...
# 4           1               Hp laser map 136 a printer kambliant
# ...       ...                                                ...
# 9072        5  Amazing product, the least to say. Excellent q...
# 9073        5  Superb Monitor. Image quality is as expected. ...
# 9074        4  What is good- No fuss entry level monitor with...
# 9075        5                        Good for working from home.
# 9076        4                                            good...
#
# [9077 rows x 2 columns]

# %%
def get_review():  #the function that scraps the URL of all the reviews and rattings
    
    driver = webdriver.Chrome(executable_path='C:\\Users\\HP\\chromedriver.exe') #Calling the Web Driver
    driver.maximize_window()
    rattings = []
    review = []

    for i in hreff1[1600:]:#--->> second DataFrame
        driver.get(i) #Opening with the URL template
        
        try: #scraping the URL of the full review pages
            link = driver.find_element_by_xpath("//a[@data-hook='see-all-reviews-link-foot']")
            link = link.get_attribute("href")
            link= link.split('ref=cm')[0]
        except:
            pass     
        
        for i in range(1,5):  #Scraping Reviews and Rattings
            l1= f'ref=cm_cr_getr_d_paging_btm_next_{i}?ie=UTF8&reviewerType=all_reviews&pageNumber={i}'
            l = link+ l1 
            
            
            driver.get(l)
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            results = soup.find_all('div',{'class' : 'a-section celwidget'})
        
            for item in results:
                    try:
                        rev = item.find('span', {'data-hook': "review-body"})
                        atag = item.find(['a'], class_ = "a-link-normal")
                        if rev.span.text.replace('\n','').strip() and atag['title'][0]:
                            review.append(rev.span.text.replace('\n','').strip())
                            rattings.append(atag['title'][0])
                        else:
                            break
                    except:
                        break
       
    driver.close()
    
    rat = pd.DataFrame({'Rattings':rattings, "Review": review})
    
    #saving the dataframe in csv
    rat.to_csv("Rattings5.csv",index=False) #Creating CSV
    
    return rat

# %%
Rat = get_review()
Rat
# Out:
#      Rattings                                             Review
# 0           1  Do not buy. Looting customers. Actual price is...
# 1           1  Bought it from Kora solutions but received a d...
# 2           5  Samsung Odyssey G7 is a great monitor for both...
# 3           1  Grainy pictures and crushed blacks in dark sce...
# 4           3  This monitor has the following issue (firmware...
# ...       ...                                                ...
# 8806        3  I bought this product due to very high range s...
# 8807        3  i got this AC1750 and replaced my TP link rout...
# 8808        4  I was using Tenda AC 10 router (since 2019) fo...
# 8809        3  Read all the reviews but was still skeptical t...
# 8810        1  Never buy this product, pure waste of money, f...
#
# [8811 rows x 2 columns]

# %%
rattings1, rattings2, rattings3, rattings4, rattings5 = pd.read_csv('Rattings1.csv'), pd.read_csv('Rattings2.csv'), pd.read_csv('Rattings3.csv'), pd.read_csv('Rattings4.csv'),pd.read_csv('Rattings5.csv')

frames = [rattings1, rattings2, rattings3, rattings4, rattings5]
Rattings = pd.concat(frames)

Rattings #we have collected 45077 records of data

Rattings.to_csv("Rattings.csv",index=False)# saving Data frame as CSV

# %%
len(Rattings)
# Out:
# 45077
